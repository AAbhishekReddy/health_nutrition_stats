# %%
import pandas as pd
import numpy as np

# %%
# This reads the excel file as an Ordered Dictionary
df = pd.read_excel('C:/Users/ghost/Desktop/BDANN/Project/x-files/HNP_statsEXCEL.xlsx', sheet_name = None)

# %%
df
# Out:
# OrderedDict([('Data',        Country Name Country Code  \
#               0        Arab World          ARB
#               1        Arab World          ARB
#               2        Arab World          ARB
#               3        Arab World          ARB
#               4        Arab World          ARB
#               5        Arab World          ARB
#               6        Arab World          ARB
#               7        Arab World          ARB
#               8        Arab World          ARB
#               9        Arab World          ARB
#               10       Arab World          ARB
#               11       Arab World          ARB
#               12       Arab World          ARB
#               13       Arab World          ARB
#               14       Arab World          ARB
#               15       Arab World          ARB
#               16       Arab World          ARB
#               17       Arab World          ARB
#               18       Arab World          ARB
# ...

# %%
# For looping through the sheets in the Excel File
for n,d in df.items():
    print('Sheet Name:{}'.format(n))
    print(d.head())
#     i = i+1
#     print(i)
# Out:
# Sheet Name:Country Code
# 0    ABW
# 1    AFG
# 2    AGO
# 3    ALB
# 4    AND
# Name: Country Code, dtype: object
# 1
# Sheet Name:Short Name
# 0          Aruba
# 1    Afghanistan
# 2         Angola
# 3        Albania
# 4        Andorra
# Name: Short Name, dtype: object
# 2
# Sheet Name:Table Name
# 0          Aruba
# 1    Afghanistan
# 2         Angola
# 3        Albania
# 4        Andorra
# Name: Table Name, dtype: object
# 3
# Sheet Name:Long Name
# 0                           Aruba
# 1    Islamic State of Afghanistan
# 2     People's Republic of Angola
# 3             Republic of Albania
# 4         Principality of Andorra
# Name: Long Name, dtype: object
# 4
# Sheet Name:2-alpha code
# 0    AW
# 1    AF
# 2    AO
# 3    AL
# 4    AD
# Name: 2-alpha code, dtype: object
# 5
# Sheet Name:Currency Unit
# 0     Aruban florin
# 1    Afghan afghani
# 2    Angolan kwanza
# 3      Albanian lek
# 4              Euro
# Name: Currency Unit, dtype: object
# 6
# Sheet Name:Special Notes
# ...

# %%
# To view the items in the ordered Dictionary
df.items()
# Out:
# odict_items([('Data',        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# 5        Arab World          ARB
# 6        Arab World          ARB
# 7        Arab World          ARB
# 8        Arab World          ARB
# 9        Arab World          ARB
# 10       Arab World          ARB
# 11       Arab World          ARB
# 12       Arab World          ARB
# 13       Arab World          ARB
# 14       Arab World          ARB
# 15       Arab World          ARB
# 16       Arab World          ARB
# 17       Arab World          ARB
# 18       Arab World          ARB
# 19       Arab World          ARB
# 20       Arab World          ARB
# 21       Arab World          ARB
# 22       Arab World          ARB
# 23       Arab World          ARB
# 24       Arab World          ARB
# 25       Arab World          ARB
# ...

# %%
df = pd.read_excel('C:/Users/ghost/Desktop/BDANN/Project/x-files/HNP_statsEXCEL.xlsx', sheet_name = 1)

# %%
data = pd.read_excel('C:/Users/ghost/Desktop/BDANN/Project/x-files/HNP_statsEXCEL.xlsx', sheet_name = 0)

# %%
series = pd.read_excel('C:/Users/ghost/Desktop/BDANN/Project/x-files/HNP_statsEXCEL.xlsx', sheet_name = 2)

# %%
c_series = pd.read_excel('C:/Users/ghost/Desktop/BDANN/Project/x-files/HNP_statsEXCEL.xlsx', sheet_name = 3)

# %%
series_t = pd.read_excel('C:/Users/ghost/Desktop/BDANN/Project/x-files/HNP_statsEXCEL.xlsx', sheet_name = 5)

# %%
foot_note = pd.read_excel('C:/Users/ghost/Desktop/BDANN/Project/x-files/HNP_statsEXCEL.xlsx', sheet_name = 'FootNote')

# %%
foot_note.head()
# Out:
#   CountryCode      SeriesCode    Year  \
# 0         ABW  SH.STA.BRTC.ZS  YR2002
# 1         ABW  SH.STA.DIAB.ZS  YR2017
# 2         ABW  SH.TBS.DTEC.ZS  YR2010
# 3         ABW  SH.TBS.DTEC.ZS  YR2011
# 4         ABW  SH.TBS.DTEC.ZS  YR2012
#
#                                          DESCRIPTION
# 0  Health situation in the americas. Basic  indic...
# 1                    Plausible bound is 9.58 - 15.13
# 2                      Uncertainty bound is 75 - 100
# 3                      Uncertainty bound is 75 - 100
# 4                      Uncertainty bound is 75 - 100
